# %%
import pickle
import os
import sys
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
with open(f"/data/abiomed_tmp/intermediate_data_d4rl/walker2d-expert-v0_413.0_1.pkl", "rb") as f:
    walker_413 = pickle.load(f)

# %%
with open(f"/data/abiomed_tmp/intermediate_data_d4rl/raw_rewards_halfcheetah-random-v0_0.05_0.pkl", "rb") as f:
    walker_413 = np.load(f)

# %%
std_files = [
    'raw_rewards_halfcheetah-random-v0_0.05_0.pkl',
    'raw_rewards_halfcheetah-random-v0_0.05_1.pkl',
    'raw_rewards_halfcheetah-random-v0_0.05_2.pkl',
    'raw_rewards_halfcheetah-random-v0_0.05_3.pkl',
]

std_arrays = []
for fname in std_files:
    with open(f'/data/abiomed_tmp/intermediate_data_d4rl/' + fname, 'rb') as f:
        std_arrays.append(np.load(f))

# Plot in subplots
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()
for i, std_data in enumerate(std_arrays):
    axes[i].hist(std_data.flatten(), bins=50, density=True, alpha=0.7, edgecolor='black')
    axes[i].set_title(f'Rewards Iteration {i}' if i >0 else 'CRPS Rewards')
    axes[i].set_xlabel('Standard Deviation')
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
std_files = [
    'raw_rewards_halfcheetah-random-v0_0.05_0.pkl',
    'raw_rewards_halfcheetah-random-v0_0.05_1.pkl',
    'raw_rewards_halfcheetah-random-v0_0.05_2.pkl',
    'raw_rewards_halfcheetah-random-v0_0.05_3.pkl',
]

std_arrays = []
for fname in std_files:
    with open(f'/data/abiomed_tmp/intermediate_data_d4rl/' + fname, 'rb') as f:
        std_arrays.append(np.load(f))

# Plot in subplots
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()
for i, std_data in enumerate(std_arrays):
    axes[i].hist(std_data.flatten(), bins=50, density=True, alpha=0.7, edgecolor='black')
    axes[i].set_title(f'Rewards Iteration {i}' if i >0 else 'CRPS Rewards')
    axes[i].set_xlabel('Standard Deviation')
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
std_files = [
    'halfcheetah-random-v0_crps_discount_0.1.pkl',
    'halfcheetah-random-v0_0.05_1.pkl',
    'halfcheetah-random-v0_0.05_2.pkl',
    'halfcheetah-random-v0_0.05_3.pkl',
    'halfcheetah-random-v0_0.05_4.pkl',
]

std_arrays = []
for fname in std_files:
    with open(f'/data/abiomed_tmp/intermediate_data_d4rl/' + fname, 'rb') as f:
        std_arrays.append(pickle.load(f))

# Plot in subplots
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()
for i, std_data in enumerate(std_arrays):
    axes[i].hist(std_data['rewards'].flatten(), bins=50, density=True, alpha=0.7, edgecolor='black')
    axes[i].set_title(f'Rewards Iteration {i}' if i >0 else 'CRPS Rewards')
    axes[i].set_xlabel('Standard Deviation')
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
std_files = [
    'std_list_halfcheetah-random-v0_1050.0_0.pkl',
    'std_list_halfcheetah-random-v0_1050.0_1.pkl',
    'std_list_halfcheetah-random-v0_1050.0_2.pkl',
    'std_list_halfcheetah-random-v0_1050.0_3.pkl',
]

std_arrays = []
for fname in std_files:
    with open(f'/data/abiomed_tmp/intermediate_data_d4rl/' + fname, 'rb') as f:
        std_arrays.append(np.load(f))

# Plot in subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()
for i, std_data in enumerate(std_arrays):
    axes[i].hist(std_data.flatten(), bins=100, density=True, alpha=0.7, edgecolor='black')
    axes[i].set_title(f'STD Penalty Iteration {i+1}')
    axes[i].set_xlabel('Standard Deviation')
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
std_files = [
    'halfcheetah-random-v0_crps_discount_0.1.pkl',
    'halfcheetah-random-v0_1050.0_1.pkl',
    'halfcheetah-random-v0_1050.0_2.pkl',
    'halfcheetah-random-v0_1050.0_3.pkl',
    'halfcheetah-random-v0_1050.0_4.pkl',
]

std_arrays = []
for fname in std_files:
    with open(f'/data/abiomed_tmp/intermediate_data_d4rl/' + fname, 'rb') as f:
        std_arrays.append(pickle.load(f))

# Plot in subplots
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()
for i, std_data in enumerate(std_arrays):
    axes[i].hist(std_data['rewards'].flatten(), bins=50, density=True, alpha=0.7, edgecolor='black')
    axes[i].set_title(f'Rewards Iteration {i}' if i > 0 else 'CRPS')
    axes[i].set_xlabel('Standard Deviation')
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
with open(f"/data/abiomed_tmp/intermediate_data_uambpo/eval_info_trainset.pkl", "rb") as f:
    eval_info = pickle.load(f)
crps_list = eval_info['eval/crps']

# %%
s

# %%
np.mean(crps_list), np.mean(std_arrays[0]),np.mean(std_arrays[1]), np.mean(std_arrays[2]), np.mean(std_arrays[3])
# Out:
# (2.79254,
#  1.8577676771084188,
#  1.8984741719620124,
#  1.9155021924122737,
#  1.8465698778323003)

# %%
# Load the arrays
std_files = [
    'std_list_train_0.45_0.pkl',
    'std_list_train_0.45_1.pkl',
    'std_list_train_0.45_2.pkl',
    'std_list_train_0.45_3.pkl',
]

std_arrays = []
for fname in std_files:
    with open(f'/data/abiomed_tmp/intermediate_data_uambpo/' + fname, 'rb') as f:
        std_arrays.append(np.load(f))

# Plot in subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

for i, std_data in enumerate(std_arrays):
    axes[i].hist(std_data.flatten(), bins=50, density=True, alpha=0.7, edgecolor='black')
    axes[i].set_title(f'STD Iteration {i+1}')
    axes[i].set_xlabel('Standard Deviation')
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.hist(std_1_0_45, bins=50, density=True, alpha=0.7, edgecolor='black')
plt.xlabel('Standard Deviation')
plt.ylabel('Density')
plt.title('Distribution of STD penalty for Abiomed')
plt.show()
plt.figure(figsize=(6, 4))
plt.hist(crps_list, bins=50, density=True, alpha=0.7, edgecolor='black')
plt.xlabel('Standard Deviation')
plt.ylabel('Density')
plt.title('Distribution of CRPS penalty for Abiomed')
plt.show()

# %%
with open(f'/data/abiomed_tmp/intermediate_data_d4rl/raw_rewards_halfcheetah-random-v0_0.05_1.pkl', 'rb') as f:
    halfcheetah_0_1_data = np.load(f)

# %%
np.mean(halfcheetah_0_1)/halfcheetah_0_1_data.mean()
# Out:
# -0.5571829685119511

# %%
std_arrays[0].mean()/ halfcheetah_0_1_data.mean()*100*1000
# Out:
# -5.3031892633989965

# %%
with open(f'/data/abiomed_tmp/intermediate_data_d4rl/halfcheetah-random-v0_crps_list.npy', 'rb') as f:
    halfcheetah_0_1 = np.load(f)

# %%
plt.figure(figsize=(6, 4))
plt.hist(halfcheetah_0_1, bins=50, density=True, alpha=0.7, edgecolor='black')
plt.xlabel('Standard Deviation')
plt.ylabel('Density')
plt.title('Distribution of CRPS penalty for halfcheetah-random')
plt.show()

# %%
# Load the arrays
std_files = [
    'std_list_halfcheetah-random-v0_0.05_0.pkl',
    'std_list_halfcheetah-random-v0_0.05_1.pkl',
    'std_list_halfcheetah-random-v0_0.05_2.pkl',
    'std_list_halfcheetah-random-v0_0.05_3.pkl',
]

std_arrays = []
for fname in std_files:
    with open(f'/data/abiomed_tmp/intermediate_data_d4rl/' + fname, 'rb') as f:
        std_arrays.append(np.load(f))

# Plot in subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

for i, std_data in enumerate(std_arrays):
    axes[i].hist(std_data.flatten(), bins=50, density=True, alpha=0.7, edgecolor='black')
    axes[i].set_title(f'STD Iteration {i+1}')
    axes[i].set_xlabel('Standard Deviation')
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
np.mean(halfcheetah_0_1), np.mean(std_arrays[0]),np.mean(std_arrays[1]), np.mean(std_arrays[2]), np.mean(std_arrays[3])
# Out:
# (0.2071506, 1.9716303e-05, 7.981172e-07, 7.5275943e-07, 7.6001993e-07)

# %%
np.mean(halfcheetah_0_1)/np.mean(std_arrays[0])
# Out:
# 10506.563

# %%
with open(f'/data/abiomed_tmp/intermediate_data_d4rl/walker2d-random-v0_crps_list.npy', 'rb') as f:
    walker_0_1 = np.load(f)

# %%
std_files = [
    'std_list_walker2d-random-v0_0.05_0.pkl',
    'std_list_walker2d-random-v0_0.05_1.pkl',
    'std_list_walker2d-random-v0_0.05_2.pkl',
    'std_list_walker2d-random-v0_0.05_3.pkl',
]

std_arrays = []
for fname in std_files:
    with open(f'/data/abiomed_tmp/intermediate_data_d4rl/' + fname, 'rb') as f:
        std_arrays.append(np.load(f))

# Plot in subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

for i, std_data in enumerate(std_arrays):
    axes[i].hist(std_data.flatten(), bins=50, density=True, alpha=0.7, edgecolor='black')
    axes[i].set_title(f'STD Iteration {i+1}')
    axes[i].set_xlabel('Standard Deviation')
    axes[i].set_ylabel('Density')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.hist(walker_0_1, bins=50, density=True, alpha=0.7, edgecolor='black')
plt.xlabel('Standard Deviation')
plt.ylabel('Density')
plt.title('Distribution of CRPS penalty for halfcheetah-random')
plt.show()

# %%
with open(f'/data/abiomed_tmp/intermediate_data_d4rl/raw_rewards_walker2d-random-v0_0.05_1.pkl', 'rb') as f:
    walker2d_0_1_data = np.load(f)

# %%
np.mean(walker_0_1)/walker2d_0_1_data.mean()
# Out:
# 0.2488615243992379

# %%
np.mean(walker_0_1), np.mean(std_arrays[0]),np.mean(std_arrays[1]), np.mean(std_arrays[2]), np.mean(std_arrays[3])
# Out:
# (0.25131208, 6.0759925e-05, 1.1461632e-06, 1.1659803e-06, 1.2776878e-06)

# %%
np.mean(walker_0_1)/np.mean(std_arrays[0])*0.1
# Out:
# 413.61484375000003

# %%
np.mean(eval_info['eval/crps']), np.std(eval_info['eval/crps'])
# Out:
# (2.79254, 2.6754386)

# %%
0.3*np.mean(eval_info['eval/crps'])
# Out:
# 0.9637403011322021

# %%
np.mean(eval_info['eval/episode_reward'])
# Out:
# -18.485710632291177

# %%
0.3*np.mean(eval_info['eval/crps'])/np.mean(eval_info['eval/episode_reward'])*100
# Out:
# -5.213433880376353

# %%
with open(f'/data/abiomed_tmp/intermediate_data_uambpo/crps_list_1.0_1.pkl', 'rb') as f:
    crps_1_0_7 = np.load(f)

# %%
with open(f'/data/abiomed_tmp/intermediate_data_uambpo/raw_rewards_1.0_0.pkl', 'rb') as f:
    raw_rwd_1_0_7 = np.load(f)

# %%
len(crps_1_0_7)
# Out:
# 28015

# %%
crps_1_0_7.mean()*0.7/raw_rwd_1_0_7.mean()*100
# Out:
# -6.4524633684769555

# %%
crps_1_0_7.mean()/np.mean(eval_info['eval/crps'])
# Out:
# 0.5663303162671844

# %%
with open(f'/data/abiomed_tmp/intermediate_data_uambpo/raw_rewards_1.0_0.pkl', 'rb') as f:
    raw_rwd_1_1_0 = np.load(f)

# %%
crps_1_1_0.mean()/np.mean(eval_info['eval/crps'])
# Out:
# 0.619476995293868

# %%
with open(f'/data/abiomed_tmp/intermediate_data_uambpo/crps_list_1.0_0.pkl', 'rb') as f:
    crps_1_1_0 = np.load(f)

# %%
crps_1_1_0
# Out:
# array([1.578074  , 1.54244075, 1.59146738, ..., 2.30524794, 2.08361704,
#        2.00386865])

# %%
crps_1_1_0.mean()
# Out:
# 1.7299143339043133

# %%
raw_rwd_1_1_0.mean()/np.mean(eval_info['eval/crps'])*-9.67512064353592/100
# Out:
# 0.619476995293868

# %%
0.6 * np.mean(eval_info['eval/crps'])/np.mean(eval_info['eval/episode_reward'])*100
# Out:
# -8.99639125190932

# %%
with open(f'/data/abiomed_tmp/intermediate_data_d4rl/halfcheetah-random-v0_crps_discount_0.1.pkl', 'rb') as f:
    offline_buffer_train = pickle.load(f)

# %%
offline_buffer_train['observations'].shape
# Out:
# (998999, 17)

# %%
with open(f'/data/abiomed_tmp/intermediate_data_d4rl/halfcheetah-random-v0_crps_discount_0.1.pkl', 'rb') as f:
    offline_buffer_train = pickle.load(f)

# %%
import pickle
import numpy as np
with open('/data/abiomed_tmp/intermediate_data_uambpo/std_list_train_0_0.pkl', 'rb') as f:
    std_list_07 = np.load(f)

# %%
with open('/data/abiomed_tmp/intermediate_data_uambpo/raw_rewards_train_0_0.pkl', 'rb') as f:
    raw_rewd = np.load(f)

# %%
std_list_07.mean()
# Out:
# 1.8589207474881997

# %%
np.mean(eval_info['eval/crps'])/std_list_07.mean()
# Out:
# 1.5022372939610769

# %%
2*np.mean(eval_info['eval/crps'])/raw_rewd.mean()*100
# Out:
# -31.676265337726612

# %%
2*1.5*std_list_07.mean()/raw_rewd.mean()*100
# Out:
# -31.62908962358714

# %%
0.6*1.5
# Out:
# 0.8999999999999999

# %%
1.5*1.5
# Out:
# 2.25

# %%
with open('/data/abiomed_tmp/intermediate_data_d4rl/halfcheetah-expert-v0_crps_list.npy', 'rb') as f:
    crps_halfcheetah_random = np.load(f)

# %% [markdown]
# abiomed:0.3-0.45 / 0.6-0.9 / 1.5-2.25/ 2-3 /
#
# halfcheetah-random: 0.1 lambda_crps 0.05 lambda_std -> 50% (0.01 10% in batch of 50 samples)

# %%
(crps_halfcheetah_random*0.1).mean()
# Out:
# 0.018962992

# %% [markdown]
# crps_halfcheetah_random.mean() = 0.18962993
#
# batch_stds.mean() = 0.29702887

# %%
(0.05 * batch_stds).mean() = 0.029

# %%
with open(f'/data/abiomed_tmp/intermediate_data_d4rl/halfcheetah-random-v0_crps_discount_0.1.pkl', 'rb') as f:
                offline_buffer_train = pickle.load(f)

# %%
offline_buffer_train['next_observations'].shape
# Out:
# (998999, 17)

# %%
with open(os.path.join('/data/abiomed_tmp/intermediate_data_d4rl',f'halfcheetah-random-v0_0.05_2.pkl'), 'rb') as f:
        dataset_train = pickle.load(f)

# %%
dataset_train['observations'].shape
# Out:
# (998950, 17)

# %%
49947500/50
# Out:
# 998950.0
